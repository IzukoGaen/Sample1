# %%
# Install once:  python -m pip install -e .
import multiplechecks3
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Looking in indexes: https://****@pkgs.dev.azure.com/msci-otw/_packaging/msci-otw-org-feed/pypi/simple
# ...

# %%
outputs, profiles = multiplechecks3.run_sanity_checks(
    "Input files/",
    "Output files/",
    clear_output=True,
    clear_input=False,
    profile=True,
)
outputs
# Out:
# Emptying Output files/ directory
# /opt/conda/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/conda/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/data/shared_win_otw/ESG Custom Services/portvic/sanityscript6.py:327: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   fact_check_ias = test_feed.iloc[ias_index, 0:2][1] != feed.iloc[ias_index, 0:2][1]
# BTW_Custom_Test3 Detailed Feed Report.xlsx Output was successfully generated!
# Emptying Input files/ directory
